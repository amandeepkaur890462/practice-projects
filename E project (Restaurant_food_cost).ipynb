# %%
import warnings
warnings.simplefilter("ignore")
import seaborn as sn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_excel("restaurant_food_cost_Data-Test.xlsx")
df1=pd.read_excel("restaurant_food_cost_Data-Train.xlsx")
print(df)
# Out:
#               TITLE  RESTAURANT_ID  \
# 0     CASUAL DINING           4085
# 1       QUICK BITES          12680
# 2     CASUAL DINING           1411
# 3              None            204
# 4       QUICK BITES          13453
# ...             ...            ...
# 4226  CASUAL DINING           9057
# 4227           None           1247
# 4228    QUICK BITES           8617
# 4229    QUICK BITES           6485
# 4230    QUICK BITES           2421
#
#                                            CUISINES  \
# 0             North Indian, Chinese, Mughlai, Kebab
# 1      South Indian, Fast Food, Pizza, North Indian
# 2           North Indian, Seafood, Biryani, Chinese
# 3                                           Biryani
# 4                              South Indian, Kerala
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# ...

# %%
df.shape
# Out:
# (4231, 8)

# %%
df.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# dtype: object

# %%
df.head()
# Out:
#            TITLE  RESTAURANT_ID                                      CUISINES  \
# 0  CASUAL DINING           4085         North Indian, Chinese, Mughlai, Kebab
# 1    QUICK BITES          12680  South Indian, Fast Food, Pizza, North Indian
# 2  CASUAL DINING           1411       North Indian, Seafood, Biryani, Chinese
# 3           None            204                                       Biryani
# 4    QUICK BITES          13453                          South Indian, Kerala
#
#                                                 TIME       CITY      LOCALITY  \
# 0                      12noon – 12midnight (Mon-Sun)      Noida     Sector 18
# 1                            7am – 12:30AM (Mon-Sun)     Mumbai    Grant Road
# 2                           11am – 11:30pm (Mon-Sun)     Mumbai  Marine Lines
# 3  9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...  Faridabad           NIT
# 4                              11am – 10pm (Mon-Sun)      Kochi        Kaloor
#
#   RATING       VOTES
# ...

# %%
print(df1)
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
df1.shape
# Out:
# (12690, 9)

# %%
df1.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %%
Fees= df1['COST'].hist(bins=60)
mean_val=np.mean(df1['COST'])
plt.axvline(mean_val,linewidth=4, color='green',label='mean COST')
plt.xlabel('COST')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
df1.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df["CUISINES_1"]=df["CUISINES"].str.split(',').str[0]
df["CUISINES_2"]=df["CUISINES"].str.split(',').str[1]
df["CUISINES_3"]=df["CUISINES"].str.split(',').str[2]
df["CUISINES_4"]=df["CUISINES"].str.split(',').str[3]
df["CUISINES_5"]=df["CUISINES"].str.split(',').str[4]
df["CUISINES_6"]=df["CUISINES"].str.split(',').str[5]
df["CUISINES_7"]=df["CUISINES"].str.split(',').str[6]

# %%
df.head(10)
# Out:
#                        TITLE  RESTAURANT_ID  \
# 0              CASUAL DINING           4085
# 1                QUICK BITES          12680
# 2              CASUAL DINING           1411
# 3                       None            204
# 4                QUICK BITES          13453
# 5  FOOD TRUCK,DESSERT PARLOR           4518
# 6              CASUAL DINING           1643
# 7              CASUAL DINING           5109
# 8                       None           5606
# 9              CASUAL DINING          14319
#
#                                        CUISINES  \
# 0         North Indian, Chinese, Mughlai, Kebab
# 1  South Indian, Fast Food, Pizza, North Indian
# 2       North Indian, Seafood, Biryani, Chinese
# 3                                       Biryani
# 4                          South Indian, Kerala
# 5                           Ice Cream, Desserts
# 6          North Indian, Street Food, Fast Food
# 7                              Biryani, Chinese
# ...

# %%
df.shape
# Out:
# (4231, 17)

# %%
df1["CUISINES_1"]=df1["CUISINES"].str.split(',').str[0]
df1["CUISINES_2"]=df1["CUISINES"].str.split(',').str[1]
df1["CUISINES_3"]=df1["CUISINES"].str.split(',').str[2]
df1["CUISINES_4"]=df1["CUISINES"].str.split(',').str[3]
df1["CUISINES_5"]=df1["CUISINES"].str.split(',').str[4]
df1["CUISINES_6"]=df1["CUISINES"].str.split(',').str[5]
df1["CUISINES_7"]=df1["CUISINES"].str.split(',').str[6]

# %%
df1.head(10)
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
# 5      CASUAL DINING           5618
# 6               CAFÉ           4383
# 7       MICROBREWERY           1249
# 8        QUICK BITES           7062
# 9        QUICK BITES          10109
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
# 5     North Indian, Chinese, Seafood, Biryani
# 6  Cafe, Chinese, Pizza, North Indian, Burger
# 7                                    Bar Food
# 8                  South Indian, North Indian
# 9                                North Indian
#
# ...

# %%
df.describe()
# Out:
#        RESTAURANT_ID  CUISINES_9
# count    4231.000000         0.0
# mean     7791.438431         NaN
# std      4458.797621         NaN
# min         3.000000         NaN
# 25%      3908.500000         NaN
# 50%      7798.000000         NaN
# 75%     11634.000000         NaN
# max     15572.000000         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4231 entries, 0 to 4230
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          4231 non-null   object
#  1   RESTAURANT_ID  4231 non-null   int64
#  2   CUISINES       4231 non-null   object
#  3   TIME           4231 non-null   object
#  4   CITY           4196 non-null   object
#  5   LOCALITY       4201 non-null   object
#  6   RATING         4229 non-null   object
#  7   VOTES          3829 non-null   object
#  8   CUISINES_1     4231 non-null   object
#  9   CUISINES_2     3246 non-null   object
#  10  CUISINES_3     1900 non-null   object
#  11  CUISINES_4     917 non-null    object
#  12  CUISINES_5     356 non-null    object
#  13  CUISINES_6     137 non-null    object
#  14  CUISINES_7     74 non-null     object
#  15  CUISINES_8     31 non-null     object
#  16  CUISINES_9     0 non-null      float64
# ...

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sn.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY               35
# LOCALITY           30
# RATING              2
# VOTES             402
# CUISINES_1          0
# CUISINES_2        985
# CUISINES_3       2331
# CUISINES_4       3314
# CUISINES_5       3875
# CUISINES_6       4094
# CUISINES_7       4157
# CUISINES_8       4200
# CUISINES_9       4231
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# TITLE                0
# RESTAURANT_ID        0
# CUISINES             0
# TIME                 0
# CITY               112
# LOCALITY            98
# RATING               2
# VOTES             1204
# COST                 0
# CUISINES_1           0
# CUISINES_2        3062
# CUISINES_3        6999
# CUISINES_4        9995
# CUISINES_5       11675
# CUISINES_6       12276
# CUISINES_7       12514
# dtype: int64

# %%
df['CITY'].fillna("NONE")
# Out:
# 0             Noida
# 1            Mumbai
# 2            Mumbai
# 3         Faridabad
# 4             Kochi
#            ...
# 4226      New Delhi
# 4227      Bangalore
# 4228      Faridabad
# 4229          Kochi
# 4230    Bandra West
# Name: CITY, Length: 4231, dtype: object

# %%
df1.isnull().sum()
# Out:
# TITLE                0
# RESTAURANT_ID        0
# CUISINES             0
# TIME                 0
# CITY               112
# LOCALITY            98
# RATING               2
# VOTES             1204
# COST                 0
# CUISINES_1           0
# CUISINES_2        3062
# CUISINES_3        6999
# CUISINES_4        9995
# CUISINES_5       11675
# CUISINES_6       12276
# CUISINES_7       12514
# dtype: int64
