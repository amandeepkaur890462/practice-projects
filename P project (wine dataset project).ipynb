# %%
import warnings
warnings.simplefilter("ignore")
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv("winedataset.csv")
print(df)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %% [markdown]
# Summary Statistics

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [markdown]
# Key Observations

# %% [markdown]
# 1. the mean is almost equal to median(50 percentile) in all columns.

# %% [markdown]
# 2.there is large difference between the max and 75 percentile in Alcalinity of ash,Flavanoids,Color intensity and Proline

# %% [markdown]
# 3. the above points 1 and 2 suggest that there are extreme outliers present  in these  four columns.

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.Class.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %% [markdown]
# Observations

# %% [markdown]
# 1) class has most values concentrated in  the category 2

# %% [markdown]
# 2) class has least values concentrated in the category 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
corr=df.corr() 
sn.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Handling outliers

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
df['Alcalinity of ash'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Flavanoids'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Color intensity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Proline    '].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (178, 14)

# %%
collist=df.columns.values
ncol=14
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sn.boxplot(df[collist[i]],color='blue', orient='v')
    plt.tight_layout()

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %%
plt.figure(figsize=(20,20))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sn.distplot(df[collist[i]])

# %% [markdown]
# alcohol and proanthocyanins are normally distributed

# %% [markdown]
# other independent variables are positively skewed

# %%
plt.scatter(df['Proanthocyanins'],df['Alcohol'])

# %%
sn.pairplot(df)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
# array([[1.21394365, 1.51861254, 0.5622498 , ..., 0.36217728, 1.84791957,
#         1.01300893],
#        [1.21394365, 0.24628963, 0.49941338, ..., 0.40605066, 1.1134493 ,
#         0.96524152],
#        [1.21394365, 0.19687903, 0.02123125, ..., 0.31830389, 0.78858745,
#         1.39514818],
#        ...,
#        [1.37386437, 0.33275817, 1.74474449, ..., 1.61212515, 1.48544548,
#         0.28057537],
#        [1.37386437, 0.20923168, 0.22769377, ..., 1.56825176, 1.40069891,
#         0.29649784],
#        [1.37386437, 1.39508604, 1.58316512, ..., 1.52437837, 1.42894777,
#         0.59516041]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df_new.shape
# Out:
# (168, 14)

# %%
df.shape
# Out:
# (178, 14)

# %% [markdown]
# Training data

# %%
x=df_new

# %%
x.shape
# Out:
# (168, 14)

# %%
y=df_new["Class"]

# %%
y.shape
# Out:
# (168,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
Scaledx=sc.fit_transform(x)

# %% [markdown]
# Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(Scaledx,y,test_size=25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        print(f" Best accuracy {accu*100} found on random_state {best_rstate} ")
# Out:
#  Best accuracy 100.0 found on random_state 30

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Scaledx,y,test_size=25,random_state=30)

# %% [markdown]
# Finding the best Model

# %% [markdown]
# LinearRegression

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(LinearRegression(),x_train,y_train,cv=5).mean()
print(f"Accuracy={r2score*100},cross_val_score={cvscore*100} & difference ={(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy=100.0,cross_val_score=100.0 & difference =0.0

# %% [markdown]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
y_pred=RF.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(RandomForestRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy={r2score*100},cross_val_score={cvscore*100} & difference ={(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy=99.99863387978142,cross_val_score=99.93827991003472 & difference =0.06035396974669993

# %% [markdown]
# AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ADB=AdaBoostRegressor()
ADB.fit(x_train,y_train)
y_pred=ADB.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(AdaBoostRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy={r2score*100},cross_val_score={cvscore*100} & difference ={(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy=86.33879781420765,cross_val_score=97.98611111111111 & difference =-11.647313296903462

# %% [markdown]
# SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
y_pred=SGD.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(SGDRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy={r2score*100},cross_val_score={cvscore*100} & difference ={(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy=94.25438089308851,cross_val_score=94.94440282927368 & difference =-0.6900219361851754

# %% [markdown]
# LinearRegression and  AdaBoostRegressor are performing the best with same accuracy and cross validation score.
# i will choose LinearRegression

# %% [markdown]
# Serialization

# %%
import joblib
joblib.dump(LR,"winedataset.pkl")
# Out:
# ['winedataset.pkl']
