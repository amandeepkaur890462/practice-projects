# %%
import warnings
warnings.simplefilter("ignore")
import seaborn as sn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv("1000 Records.csv")
print(df)
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
df.shape
# Out:
# (1000, 37)

# %%
df.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df=df.rename(columns={'Age in Yrs.':'Age','Weight in Kgs':'Weight','Age in Company(Years)':'Age in Company'})
df.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# Summary Statistics

# %%
df.describe()
# Out:
#               Emp ID          Age  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %% [markdown]
# Key Observations

# %% [markdown]
# 1. the mean is grater than median(50 percentile) in all columns.

# %% [markdown]
# 2.there is large difference between the max and 75 percentile in Age in yrs.,year of joining ,age in company,salary and zip

# %% [markdown]
# 3.the above points 1 and 2 suggest that there are extreme outliers present in these five columns.

# %%
df.Salary.unique()
# Out:
# array([119090, 117991, 161045, 142616, 135706, 173027,  41287,  85833,
#        154216, 133003, 154836, 124757,  58733,  75584, 118693,  98381,
#        102274,  91719, 150016, 125232, 179264,  68134, 118621,  85864,
#         98030, 149842,  79476, 105366,  53311, 122631,  45210, 115858,
#        178750, 115574, 118607,  98990, 139394,  63525, 185105,  48443,
#         44198, 169620, 125299, 132431, 118525, 127772,  67442,  96197,
#         96641, 145181, 199943, 144517,  94221,  84824, 143864, 104197,
#         80844,  87962, 125428,  66575, 192498, 116635, 108511, 110021,
#        124074, 176165,  87146,  62435, 161871,  97656,  98023, 103749,
#        176095, 160494, 112988, 128425,  93355, 154843, 131543, 107957,
#         89172,  84151, 153345, 173372, 180468, 107647, 190709,  97725,
#        178073,  42840, 161106,  98604, 159223, 188022, 139662,  80629,
#        180062, 104764, 171662, 197951, 188137, 160421, 125044, 176750,
# ...

# %%
df.Salary.value_counts()
# Out:
# 173372    2
# 136817    2
# 174027    2
# 66212     1
# 115356    1
#          ..
# 60737     1
# 175424    1
# 197951    1
# 53311     1
# 186371    1
# Name: Salary, Length: 997, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age                     1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Middle Initial            0
# Last Name                 0
# Gender                    0
# E Mail                    0
# Father's Name             0
# Mother's Name             0
# Mother's Maiden Name      0
# Date of Birth             0
# Time of Birth             0
# Age                       0
# Weight in Kgs.            0
# Date of Joining           0
# Quarter of Joining        0
# Half of Joining           0
# Year of Joining           0
# Month of Joining          0
# Month Name of Joining     0
# Short Month               0
# Day of Joining            0
# DOW of Joining            0
# Short DOW                 0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# SSN                       0
# Phone No.                 0
# Place Name                0
# County                    0
# City                      0
# State                     0
# ...

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
corr=df.corr() 
sn.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Handling outliers

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Year of Joining'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Salary'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Zip'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# Emp ID                    0.029501
# Age                       0.006173
# Weight in Kgs.            0.657110
# Year of Joining          -0.958797
# Month of Joining          0.057287
# Day of Joining           -0.143305
# Age in Company (Years)    0.968211
# Salary                    0.034356
# Zip                       0.147698
# dtype: float64

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
plt.scatter(df['Age in Company (Years)'],df['Salary'])

# %%
plt.scatter(df['County'],df['Salary'])

# %%
sn.pairplot(df)
